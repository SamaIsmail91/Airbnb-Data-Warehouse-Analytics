# %%
import pandas as pd
file = pd.read_csv("c:\Users\Sh2\Desktop\nba.csv")
print(file.info())
print(file.describe())
columns=file.columns
print(columns)
null_columns = file.column[file.isnull().any()]
print(null_columns)
file=file.dropna(subset=[file.columns[1]])
print(file)
file = file.sort_values(by='Customer Id')
x=file.fillna("sales", inplace=True)
print(x)
file = file.drop_duplicates()
print(file)
